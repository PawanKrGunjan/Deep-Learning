# %%
# !pip install numba
#!pip install scikit-learn
#!pip install pydot
# Out:
# Collecting numba
#   Downloading numba-0.56.4-cp310-cp310-win_amd64.whl (2.5 MB)
#      ---------------------------------------- 2.5/2.5 MB 6.8 MB/s eta 0:00:00
# Requirement already satisfied: numpy<1.24,>=1.18 in e:\g-python\lib\site-packages (from numba) (1.23.1)
# Requirement already satisfied: setuptools in e:\g-python\lib\site-packages (from numba) (62.6.0)
# Collecting llvmlite<0.40,>=0.39.0dev0
#   Downloading llvmlite-0.39.1-cp310-cp310-win_amd64.whl (23.2 MB)
#      ---------------------------------------- 23.2/23.2 MB 5.8 MB/s eta 0:00:00
# Installing collected packages: llvmlite, numba
# Successfully installed llvmlite-0.39.1 numba-0.56.4

# %%
import gc
import os
import math
import numpy as np
import pandas as pd
from numba import njit
from numpy import sqrt, sin, cos, pi, zeros
from numpy.random import randn, rand, uniform, normal
from scipy.linalg import hadamard
import tensorflow as tf
from tensorflow.keras.utils import plot_model
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.layers import Input, Dense, Activation, LSTM, Dropout, RepeatVector, TimeDistributed, Embedding, Reshape, Dot, Concatenate
from tensorflow.keras.layers import GRU, SpatialDropout1D, Conv1D, GlobalMaxPooling1D,Multiply, Lambda, Softmax, Flatten, BatchNormalization, Bidirectional, dot, concatenate
from tensorflow.keras.layers import AdditiveAttention, Attention
from tensorflow.keras.activations import relu
from tensorflow.keras.optimizers import Adam
from tensorflow.keras import callbacks
from tensorflow.keras import backend
from tensorflow.keras.utils import plot_model
from tensorflow.keras.metrics import MeanSquaredError
from sklearn.preprocessing import StandardScaler
import matplotlib.pyplot as plt
from tqdm.notebook import tqdm

print("Tensorflow version " + tf.__version__)
AUTO = tf.data.experimental.AUTOTUNE
# Out:
# Tensorflow version 2.8.3

# %% [markdown]
# # Configurations

# %%
# Detect hardware, return appropriate distribution strategy
try:
    # TPU detection. No parameters necessary if TPU_NAME environment variable is set.
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver()  
    print('Running on TPU ', tpu.master())
except ValueError:
    tpu = None

if tpu:
    tf.config.experimental_connect_to_cluster(tpu)
    tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.experimental.TPUStrategy(tpu)
else:
    # default distribution strategy in Tensorflow. Works on CPU and single GPU.
    strategy = tf.distribute.get_strategy() 

print("REPLICAS: ", strategy.num_replicas_in_sync)
# Out:
# REPLICAS:  1

# %%
MIXED_PRECISION = False
XLA_ACCELERATE = True

if MIXED_PRECISION:
    from tensorflow.keras.mixed_precision import experimental as mixed_precision
    if tpu: policy = tf.keras.mixed_precision.experimental.Policy('mixed_bfloat16')
    else: policy = tf.keras.mixed_precision.experimental.Policy('mixed_float16')
    mixed_precision.set_policy(policy)
    print('Mixed precision enabled')

if XLA_ACCELERATE:
    tf.config.optimizer.set_jit(True)
    print('Accelerated Linear Algebra enabled')
# Out:
# Accelerated Linear Algebra enabled

# %% [markdown]
# # Read Data

# %%
lotto = pd.read_csv('lotto_history.csv', index_col = 'Date')
lotto.head()
# Out:
#             Ball_1  Ball_2  Ball_3  Ball_4  Ball_5  Ball_6  Ball_Bonus
# Date
# 2016-01-02      12      25      29      40      48      56          52
# 2016-01-06       8      30      40      50      54      57          13
# 2016-01-09      26      27      46      47      52      58          48
# 2016-01-13       4      12      38      46      57      59           8
# 2016-01-16       1       8      12      25      43      52          38

# %% [markdown]
# # Train Test Split
# Use the last 50 draws as the test dataset
# Use a sliding window of 10 to split the input data

# %%
data = lotto.values - 1
train = data[:-50]
test = data[-50:]

w = 10
X_train = []
y_train = []
for i in range(w, len(train)):
    X_train.append(train[i - w: i, :])
    y_train.append(train[i])
X_train, y_train = np.array(X_train), np.array(y_train)

inputs = data[data.shape[0] - test.shape[0] - w:]
X_test = []
for i in range(w, inputs.shape[0]):
    X_test.append(inputs[i - w: i, :])
X_test = np.array(X_test)
y_test = test

# %%
print(data.shape)
print(X_train.shape)
print(y_train.shape)
print(X_test.shape)
print(y_test.shape)
# Out:
# (485, 7)
# (425, 10, 7)
# (425, 7)
# (50, 10, 7)
# (50, 7)

# %% [markdown]
# # Seq2Seq Model to Predict Future Draws

# %% [markdown]
# Input the last 10 draws and sequentially predict the next draw.
# Monitor the performance by sparse categorical crossentropy and sparse top k categorical accuracy.

# %%
embed_dim = (59 // 2) + 1
dropout_rate = 0.5
spatial_dropout_rate = 0.5
steps_before = w
steps_after = 7
feature_count = embed_dim * 7
hidden_neurons = [64, 32] 
bidirectional = True 
attention_style = 'Bahdanau'

# %%
with strategy.scope():
    
    inp0 = Input(shape = (w, X_train.shape[2]))
    
    # Embed 59 categories into a 30-dimension continuous-number vector for each ball
    inp1 = Lambda(lambda x: x[:, :, 0])(inp0)
    inp1 = Embedding(59, embed_dim)(inp1)
    inp1 = SpatialDropout1D(spatial_dropout_rate)(inp1)
    
    inp2 = Lambda(lambda x: x[:, :, 1])(inp0)
    inp2 = Embedding(59, embed_dim)(inp2)
    inp2 = SpatialDropout1D(spatial_dropout_rate)(inp2)
    
    inp3 = Lambda(lambda x: x[:, :, 2])(inp0)
    inp3 = Embedding(59, embed_dim)(inp3)
    inp3 = SpatialDropout1D(spatial_dropout_rate)(inp3)
    
    inp4 = Lambda(lambda x: x[:, :, 3])(inp0)
    inp4 = Embedding(59, embed_dim)(inp4)
    inp4 = SpatialDropout1D(spatial_dropout_rate)(inp4)
    
    inp5 = Lambda(lambda x: x[:, :, 4])(inp0)
    inp5 = Embedding(59, embed_dim)(inp5)
    inp5 = SpatialDropout1D(spatial_dropout_rate)(inp5)    
    
    inp6 = Lambda(lambda x: x[:, :, 5])(inp0)
    inp6 = Embedding(59, embed_dim)(inp6)
    inp6 = SpatialDropout1D(spatial_dropout_rate)(inp6)
    
    inp7 = Lambda(lambda x: x[:, :, 6])(inp0)
    inp7 = Embedding(59, embed_dim)(inp7)
    inp7 = SpatialDropout1D(spatial_dropout_rate)(inp7)
    
    inp = Concatenate()([inp1, inp2, inp3, inp4, inp5, inp6, inp7])
    
    # Seq2Seq model with attention or bidirectional encoder
    
    num_layers = len(hidden_neurons)
    
    sh_list, h_list, c_list = [inp], [], []
    
    if bidirectional:
        
        for i in range(num_layers):
    
            sh, fh, fc, bh, bc = Bidirectional(LSTM(hidden_neurons[i],
                                                    dropout = dropout_rate, 
                                                    return_state = True, 
                                                    return_sequences = True))(sh_list[-1])
        
            h = Concatenate()([fh, bh])
            c = Concatenate()([fc, bc]) 

            sh_list.append(sh)
            h_list.append(h)
            c_list.append(c)
        
    else:
    
        for i in range(num_layers):

            sh, h, c = LSTM(hidden_neurons[i], 
                            dropout = dropout_rate,
                            return_state = True, 
                            return_sequences = True)(sh_list[-1])

            sh_list.append(sh)
            h_list.append(h)
            c_list.append(c)
    
    decoder = RepeatVector(steps_after)(h_list[-1])
    
    if bidirectional:
        
        decoder_hidden_neurons = [hn * 2 for hn in hidden_neurons]
        
    else:
        
        decoder_hidden_neurons = hidden_neurons
    
    for i in range(num_layers):
        
        decoder = LSTM(decoder_hidden_neurons[i],
                       dropout = dropout_rate, 
                       return_sequences = True)(decoder, initial_state = [h_list[i], c_list[i]])
       
    if attention_style == 'Bahdanau':
        
        context = AdditiveAttention(dropout = dropout_rate)([decoder, sh_list[-1]])
        
        decoder = concatenate([context, decoder])
        
    elif attention_style == 'Luong':
        
        context = Attention(dropout = dropout_rate)([decoder, sh_list[-1]])
        
        decoder = concatenate([context, decoder])
    
    out = Dense(59, activation = 'softmax')(decoder)

    model = Model(inputs = inp0, outputs = out)
    
    sparse_top_k = tf.keras.metrics.SparseTopKCategoricalAccuracy(k = 5, name = 'sparse_top_k')

    model.compile(optimizer = 'adam', loss = 'sparse_categorical_crossentropy', metrics = [sparse_top_k])

# %%
model.summary()
# Out:
# Model: "model"
# __________________________________________________________________________________________________
#  Layer (type)                   Output Shape         Param #     Connected to
# ==================================================================================================
#  input_1 (InputLayer)           [(None, 10, 7)]      0           []
#
#  lambda (Lambda)                (None, 10)           0           ['input_1[0][0]']
#
#  lambda_1 (Lambda)              (None, 10)           0           ['input_1[0][0]']
#
#  lambda_2 (Lambda)              (None, 10)           0           ['input_1[0][0]']
#
#  lambda_3 (Lambda)              (None, 10)           0           ['input_1[0][0]']
#
#  lambda_4 (Lambda)              (None, 10)           0           ['input_1[0][0]']
#
#  lambda_5 (Lambda)              (None, 10)           0           ['input_1[0][0]']
#
#  lambda_6 (Lambda)              (None, 10)           0           ['input_1[0][0]']
#
#  embedding (Embedding)          (None, 10, 30)       1770        ['lambda[0][0]']
#
#  embedding_1 (Embedding)        (None, 10, 30)       1770        ['lambda_1[0][0]']
#
#  embedding_2 (Embedding)        (None, 10, 30)       1770        ['lambda_2[0][0]']
#
#  embedding_3 (Embedding)        (None, 10, 30)       1770        ['lambda_3[0][0]']
#
#  embedding_4 (Embedding)        (None, 10, 30)       1770        ['lambda_4[0][0]']
#
#  embedding_5 (Embedding)        (None, 10, 30)       1770        ['lambda_5[0][0]']
#
#  embedding_6 (Embedding)        (None, 10, 30)       1770        ['lambda_6[0][0]']
#
#  spatial_dropout1d (SpatialDrop  (None, 10, 30)      0           ['embedding[0][0]']
#  out1D)
#
#  spatial_dropout1d_1 (SpatialDr  (None, 10, 30)      0           ['embedding_1[0][0]']
#  opout1D)
#
#  spatial_dropout1d_2 (SpatialDr  (None, 10, 30)      0           ['embedding_2[0][0]']
#  opout1D)
#
#  spatial_dropout1d_3 (SpatialDr  (None, 10, 30)      0           ['embedding_3[0][0]']
#  opout1D)
#
#  spatial_dropout1d_4 (SpatialDr  (None, 10, 30)      0           ['embedding_4[0][0]']
#  opout1D)
#
#  spatial_dropout1d_5 (SpatialDr  (None, 10, 30)      0           ['embedding_5[0][0]']
#  opout1D)
#
#  spatial_dropout1d_6 (SpatialDr  (None, 10, 30)      0           ['embedding_6[0][0]']
#  opout1D)
#
#  concatenate (Concatenate)      (None, 10, 210)      0           ['spatial_dropout1d[0][0]',
#                                                                   'spatial_dropout1d_1[0][0]',
#                                                                   'spatial_dropout1d_2[0][0]',
#                                                                   'spatial_dropout1d_3[0][0]',
#                                                                   'spatial_dropout1d_4[0][0]',
#                                                                   'spatial_dropout1d_5[0][0]',
#                                                                   'spatial_dropout1d_6[0][0]']
#
#  bidirectional (Bidirectional)  [(None, 10, 128),    140800      ['concatenate[0][0]']
#                                  (None, 64),
#                                  (None, 64),
#                                  (None, 64),
#                                  (None, 64)]
#
#  bidirectional_1 (Bidirectional  [(None, 10, 64),    41216       ['bidirectional[0][0]']
#  )                               (None, 32),
#                                  (None, 32),
#                                  (None, 32),
#                                  (None, 32)]
#
#  concatenate_3 (Concatenate)    (None, 64)           0           ['bidirectional_1[0][1]',
#                                                                   'bidirectional_1[0][3]']
#
#  repeat_vector (RepeatVector)   (None, 7, 64)        0           ['concatenate_3[0][0]']
#
#  concatenate_1 (Concatenate)    (None, 128)          0           ['bidirectional[0][1]',
#                                                                   'bidirectional[0][3]']
#
#  concatenate_2 (Concatenate)    (None, 128)          0           ['bidirectional[0][2]',
#                                                                   'bidirectional[0][4]']
#
#  lstm_2 (LSTM)                  (None, 7, 128)       98816       ['repeat_vector[0][0]',
#                                                                   'concatenate_1[0][0]',
#                                                                   'concatenate_2[0][0]']
#
#  concatenate_4 (Concatenate)    (None, 64)           0           ['bidirectional_1[0][2]',
#                                                                   'bidirectional_1[0][4]']
#
#  lstm_3 (LSTM)                  (None, 7, 64)        49408       ['lstm_2[0][0]',
#                                                                   'concatenate_3[0][0]',
#                                                                   'concatenate_4[0][0]']
#
#  additive_attention (AdditiveAt  (None, 7, 64)       64          ['lstm_3[0][0]',
#  tention)                                                         'bidirectional_1[0][0]']
#
#  concatenate_5 (Concatenate)    (None, 7, 128)       0           ['additive_attention[0][0]',
#                                                                   'lstm_3[0][0]']
#
#  dense (Dense)                  (None, 7, 59)        7611        ['concatenate_5[0][0]']
#
# ==================================================================================================
# Total params: 350,305
# Trainable params: 350,305
# Non-trainable params: 0
# __________________________________________________________________________________________________

# %%
plot_model(model, 
           to_file='lotto_prediction.png',
           show_shapes = True, 
           show_dtype=True,
           show_layer_names = True, 
           rankdir = 'LR', #'TB',
           expand_nested=True,
           dpi = 70,
           show_layer_activations = True)

# %%
plot_model(model, 
           to_file='Lotto_Prediction.png',
           show_shapes = True, 
           show_dtype=True,
           show_layer_names = True, 
           rankdir ='TB',
           expand_nested=True,
           dpi = 100,
           show_layer_activations = True)

# %%
class CosineAnnealingScheduler(callbacks.Callback):
    """Cosine annealing scheduler.
    """

    def __init__(self, T_max, eta_max, eta_min = 0, verbose = 0):
        super(CosineAnnealingScheduler, self).__init__()
        self.T_max = T_max
        self.eta_max = eta_max
        self.eta_min = eta_min
        self.verbose = verbose

    def on_epoch_begin(self, epoch, logs = None):
        if not hasattr(self.model.optimizer, 'lr'):
            raise ValueError('Optimizer must have a "lr" attribute.')
        lr = self.eta_min + (self.eta_max - self.eta_min) * (1 + math.cos(math.pi * epoch / self.T_max)) / 2
        backend.set_value(self.model.optimizer.lr, lr)
        if self.verbose > 0:
            print('\nEpoch %05d: CosineAnnealingScheduler setting learning '
                  'rate to %s.' % (epoch + 1, lr))

    def on_epoch_end(self, epoch, logs = None):
        logs = logs or {}
        logs['lr'] = backend.get_value(self.model.optimizer.lr)

# %%
EPOCHS = 200
BATCH_SIZE = 32
LR_MAX = 1e-4
LR_MIN = 1e-5

cas = CosineAnnealingScheduler(EPOCHS, LR_MAX, LR_MIN)

ckp = callbacks.ModelCheckpoint('best_model.hdf5', monitor = 'val_sparse_top_k', verbose = 0, 
                                save_best_only = True, save_weights_only = False, mode = 'max')

history = model.fit(X_train, y_train, 
                    validation_data = (X_test, y_test), 
                    callbacks = [ckp, cas], 
                    epochs = EPOCHS, 
                    batch_size = BATCH_SIZE, 
                    verbose = 2)

hist = pd.DataFrame(history.history)
# Out:
# Epoch 1/200
# 14/14 - 10s - loss: 4.0777 - sparse_top_k: 0.0793 - val_loss: 4.0773 - val_sparse_top_k: 0.1000 - lr: 1.0000e-04 - 10s/epoch - 742ms/step
# Epoch 2/200
# 14/14 - 0s - loss: 4.0768 - sparse_top_k: 0.0928 - val_loss: 4.0771 - val_sparse_top_k: 0.0886 - lr: 9.9994e-05 - 290ms/epoch - 21ms/step
# Epoch 3/200
# 14/14 - 0s - loss: 4.0763 - sparse_top_k: 0.1099 - val_loss: 4.0769 - val_sparse_top_k: 0.0743 - lr: 9.9978e-05 - 292ms/epoch - 21ms/step
# Epoch 4/200
# 14/14 - 0s - loss: 4.0757 - sparse_top_k: 0.1012 - val_loss: 4.0767 - val_sparse_top_k: 0.0686 - lr: 9.9950e-05 - 289ms/epoch - 21ms/step
# Epoch 5/200
# 14/14 - 0s - loss: 4.0748 - sparse_top_k: 0.1103 - val_loss: 4.0764 - val_sparse_top_k: 0.0743 - lr: 9.9911e-05 - 284ms/epoch - 20ms/step
# Epoch 6/200
# 14/14 - 0s - loss: 4.0743 - sparse_top_k: 0.1045 - val_loss: 4.0760 - val_sparse_top_k: 0.0714 - lr: 9.9861e-05 - 287ms/epoch - 20ms/step
# Epoch 7/200
# 14/14 - 0s - loss: 4.0737 - sparse_top_k: 0.1136 - val_loss: 4.0756 - val_sparse_top_k: 0.0800 - lr: 9.9800e-05 - 279ms/epoch - 20ms/step
# Epoch 8/200
# 14/14 - 0s - loss: 4.0718 - sparse_top_k: 0.1133 - val_loss: 4.0747 - val_sparse_top_k: 0.0771 - lr: 9.9728e-05 - 288ms/epoch - 21ms/step
# Epoch 9/200
# 14/14 - 0s - loss: 4.0707 - sparse_top_k: 0.1180 - val_loss: 4.0735 - val_sparse_top_k: 0.0829 - lr: 9.9645e-05 - 306ms/epoch - 22ms/step
# Epoch 10/200
# 14/14 - 0s - loss: 4.0677 - sparse_top_k: 0.1213 - val_loss: 4.0715 - val_sparse_top_k: 0.0971 - lr: 9.9551e-05 - 313ms/epoch - 22ms/step
# Epoch 11/200
# 14/14 - 0s - loss: 4.0629 - sparse_top_k: 0.1261 - val_loss: 4.0677 - val_sparse_top_k: 0.0857 - lr: 9.9446e-05 - 319ms/epoch - 23ms/step
# Epoch 12/200
# 14/14 - 0s - loss: 4.0540 - sparse_top_k: 0.1277 - val_loss: 4.0606 - val_sparse_top_k: 0.0914 - lr: 9.9330e-05 - 330ms/epoch - 24ms/step
# Epoch 13/200
# 14/14 - 0s - loss: 4.0353 - sparse_top_k: 0.1261 - val_loss: 4.0503 - val_sparse_top_k: 0.0829 - lr: 9.9203e-05 - 316ms/epoch - 23ms/step
# Epoch 14/200
# 14/14 - 0s - loss: 4.0107 - sparse_top_k: 0.1308 - val_loss: 4.0455 - val_sparse_top_k: 0.0857 - lr: 9.9065e-05 - 328ms/epoch - 23ms/step
# Epoch 15/200
# 14/14 - 0s - loss: 3.9889 - sparse_top_k: 0.1462 - val_loss: 4.0312 - val_sparse_top_k: 0.1114 - lr: 9.8916e-05 - 382ms/epoch - 27ms/step
# Epoch 16/200
# 14/14 - 0s - loss: 3.9631 - sparse_top_k: 0.1593 - val_loss: 4.0029 - val_sparse_top_k: 0.1229 - lr: 9.8757e-05 - 367ms/epoch - 26ms/step
# Epoch 17/200
# 14/14 - 0s - loss: 3.9282 - sparse_top_k: 0.1818 - val_loss: 3.9641 - val_sparse_top_k: 0.1543 - lr: 9.8586e-05 - 356ms/epoch - 25ms/step
# Epoch 18/200
# 14/14 - 0s - loss: 3.8913 - sparse_top_k: 0.1956 - val_loss: 3.9273 - val_sparse_top_k: 0.1714 - lr: 9.8405e-05 - 349ms/epoch - 25ms/step
# Epoch 19/200
# 14/14 - 0s - loss: 3.8544 - sparse_top_k: 0.1946 - val_loss: 3.8983 - val_sparse_top_k: 0.1714 - lr: 9.8213e-05 - 291ms/epoch - 21ms/step
# Epoch 20/200
# 14/14 - 0s - loss: 3.8260 - sparse_top_k: 0.2087 - val_loss: 3.8729 - val_sparse_top_k: 0.1800 - lr: 9.8011e-05 - 362ms/epoch - 26ms/step
# Epoch 21/200
# 14/14 - 0s - loss: 3.8074 - sparse_top_k: 0.2057 - val_loss: 3.8578 - val_sparse_top_k: 0.1743 - lr: 9.7798e-05 - 322ms/epoch - 23ms/step
# Epoch 22/200
# 14/14 - 0s - loss: 3.7864 - sparse_top_k: 0.2097 - val_loss: 3.8461 - val_sparse_top_k: 0.1771 - lr: 9.7574e-05 - 347ms/epoch - 25ms/step
# Epoch 23/200
# 14/14 - 0s - loss: 3.7778 - sparse_top_k: 0.2151 - val_loss: 3.8339 - val_sparse_top_k: 0.1771 - lr: 9.7340e-05 - 303ms/epoch - 22ms/step
# Epoch 24/200
# 14/14 - 0s - loss: 3.7700 - sparse_top_k: 0.2232 - val_loss: 3.8326 - val_sparse_top_k: 0.1743 - lr: 9.7095e-05 - 354ms/epoch - 25ms/step
# Epoch 25/200
# 14/14 - 0s - loss: 3.7628 - sparse_top_k: 0.2175 - val_loss: 3.8189 - val_sparse_top_k: 0.1800 - lr: 9.6840e-05 - 332ms/epoch - 24ms/step
# Epoch 26/200
# 14/14 - 0s - loss: 3.7440 - sparse_top_k: 0.2323 - val_loss: 3.8117 - val_sparse_top_k: 0.1800 - lr: 9.6575e-05 - 326ms/epoch - 23ms/step
# Epoch 27/200
# 14/14 - 0s - loss: 3.7420 - sparse_top_k: 0.2306 - val_loss: 3.8083 - val_sparse_top_k: 0.1743 - lr: 9.6299e-05 - 313ms/epoch - 22ms/step
# Epoch 28/200
# 14/14 - 0s - loss: 3.7294 - sparse_top_k: 0.2333 - val_loss: 3.8038 - val_sparse_top_k: 0.1714 - lr: 9.6013e-05 - 316ms/epoch - 23ms/step
# Epoch 29/200
# 14/14 - 0s - loss: 3.7271 - sparse_top_k: 0.2363 - val_loss: 3.7983 - val_sparse_top_k: 0.1743 - lr: 9.5717e-05 - 373ms/epoch - 27ms/step
# Epoch 30/200
# 14/14 - 0s - loss: 3.7251 - sparse_top_k: 0.2252 - val_loss: 3.7942 - val_sparse_top_k: 0.1771 - lr: 9.5411e-05 - 331ms/epoch - 24ms/step
# Epoch 31/200
# 14/14 - 0s - loss: 3.7168 - sparse_top_k: 0.2333 - val_loss: 3.7866 - val_sparse_top_k: 0.1800 - lr: 9.5095e-05 - 301ms/epoch - 22ms/step
# Epoch 32/200
# 14/14 - 0s - loss: 3.7127 - sparse_top_k: 0.2353 - val_loss: 3.7851 - val_sparse_top_k: 0.1771 - lr: 9.4769e-05 - 307ms/epoch - 22ms/step
# Epoch 33/200
# 14/14 - 0s - loss: 3.7105 - sparse_top_k: 0.2407 - val_loss: 3.7854 - val_sparse_top_k: 0.1857 - lr: 9.4434e-05 - 380ms/epoch - 27ms/step
# Epoch 34/200
# 14/14 - 0s - loss: 3.7083 - sparse_top_k: 0.2299 - val_loss: 3.7790 - val_sparse_top_k: 0.1800 - lr: 9.4088e-05 - 362ms/epoch - 26ms/step
# Epoch 35/200
# 14/14 - 0s - loss: 3.7027 - sparse_top_k: 0.2407 - val_loss: 3.7799 - val_sparse_top_k: 0.1886 - lr: 9.3733e-05 - 413ms/epoch - 29ms/step
# Epoch 36/200
# 14/14 - 0s - loss: 3.6970 - sparse_top_k: 0.2444 - val_loss: 3.7740 - val_sparse_top_k: 0.1943 - lr: 9.3369e-05 - 393ms/epoch - 28ms/step
# Epoch 37/200
# 14/14 - 0s - loss: 3.6908 - sparse_top_k: 0.2464 - val_loss: 3.7715 - val_sparse_top_k: 0.1914 - lr: 9.2995e-05 - 319ms/epoch - 23ms/step
# Epoch 38/200
# 14/14 - 0s - loss: 3.6801 - sparse_top_k: 0.2508 - val_loss: 3.7691 - val_sparse_top_k: 0.2000 - lr: 9.2611e-05 - 413ms/epoch - 29ms/step
# Epoch 39/200
# 14/14 - 0s - loss: 3.6893 - sparse_top_k: 0.2329 - val_loss: 3.7649 - val_sparse_top_k: 0.1829 - lr: 9.2219e-05 - 331ms/epoch - 24ms/step
# Epoch 40/200
# 14/14 - 0s - loss: 3.6856 - sparse_top_k: 0.2407 - val_loss: 3.7663 - val_sparse_top_k: 0.1971 - lr: 9.1817e-05 - 315ms/epoch - 22ms/step
# Epoch 41/200
# 14/14 - 0s - loss: 3.6841 - sparse_top_k: 0.2370 - val_loss: 3.7637 - val_sparse_top_k: 0.1800 - lr: 9.1406e-05 - 324ms/epoch - 23ms/step
# Epoch 42/200
# 14/14 - 0s - loss: 3.6768 - sparse_top_k: 0.2397 - val_loss: 3.7607 - val_sparse_top_k: 0.2086 - lr: 9.0986e-05 - 388ms/epoch - 28ms/step
# Epoch 43/200
# 14/14 - 0s - loss: 3.6684 - sparse_top_k: 0.2477 - val_loss: 3.7562 - val_sparse_top_k: 0.2000 - lr: 9.0557e-05 - 324ms/epoch - 23ms/step
# Epoch 44/200
# 14/14 - 0s - loss: 3.6741 - sparse_top_k: 0.2457 - val_loss: 3.7553 - val_sparse_top_k: 0.1943 - lr: 9.0119e-05 - 336ms/epoch - 24ms/step
# Epoch 45/200
# 14/14 - 0s - loss: 3.6621 - sparse_top_k: 0.2518 - val_loss: 3.7515 - val_sparse_top_k: 0.2057 - lr: 8.9673e-05 - 362ms/epoch - 26ms/step
# Epoch 46/200
# 14/14 - 0s - loss: 3.6611 - sparse_top_k: 0.2497 - val_loss: 3.7524 - val_sparse_top_k: 0.2086 - lr: 8.9218e-05 - 321ms/epoch - 23ms/step
# Epoch 47/200
# 14/14 - 0s - loss: 3.6545 - sparse_top_k: 0.2568 - val_loss: 3.7481 - val_sparse_top_k: 0.1914 - lr: 8.8755e-05 - 322ms/epoch - 23ms/step
# Epoch 48/200
# 14/14 - 0s - loss: 3.6519 - sparse_top_k: 0.2534 - val_loss: 3.7451 - val_sparse_top_k: 0.2057 - lr: 8.8283e-05 - 330ms/epoch - 24ms/step
# Epoch 49/200
# 14/14 - 0s - loss: 3.6563 - sparse_top_k: 0.2481 - val_loss: 3.7484 - val_sparse_top_k: 0.1857 - lr: 8.7804e-05 - 312ms/epoch - 22ms/step
# Epoch 50/200
# 14/14 - 0s - loss: 3.6470 - sparse_top_k: 0.2578 - val_loss: 3.7404 - val_sparse_top_k: 0.1971 - lr: 8.7316e-05 - 325ms/epoch - 23ms/step
# Epoch 51/200
# 14/14 - 0s - loss: 3.6493 - sparse_top_k: 0.2481 - val_loss: 3.7431 - val_sparse_top_k: 0.2000 - lr: 8.6820e-05 - 326ms/epoch - 23ms/step
# Epoch 52/200
# 14/14 - 0s - loss: 3.6355 - sparse_top_k: 0.2508 - val_loss: 3.7405 - val_sparse_top_k: 0.1943 - lr: 8.6316e-05 - 316ms/epoch - 23ms/step
# Epoch 53/200
# 14/14 - 0s - loss: 3.6437 - sparse_top_k: 0.2497 - val_loss: 3.7329 - val_sparse_top_k: 0.2057 - lr: 8.5805e-05 - 341ms/epoch - 24ms/step
# Epoch 54/200
# 14/14 - 0s - loss: 3.6394 - sparse_top_k: 0.2602 - val_loss: 3.7358 - val_sparse_top_k: 0.2029 - lr: 8.5286e-05 - 354ms/epoch - 25ms/step
# Epoch 55/200
# 14/14 - 0s - loss: 3.6317 - sparse_top_k: 0.2487 - val_loss: 3.7315 - val_sparse_top_k: 0.2086 - lr: 8.4759e-05 - 376ms/epoch - 27ms/step
# Epoch 56/200
# 14/14 - 0s - loss: 3.6271 - sparse_top_k: 0.2635 - val_loss: 3.7292 - val_sparse_top_k: 0.1914 - lr: 8.4225e-05 - 388ms/epoch - 28ms/step
# Epoch 57/200
# 14/14 - 0s - loss: 3.6297 - sparse_top_k: 0.2518 - val_loss: 3.7319 - val_sparse_top_k: 0.2086 - lr: 8.3684e-05 - 390ms/epoch - 28ms/step
# Epoch 58/200
# 14/14 - 0s - loss: 3.6246 - sparse_top_k: 0.2461 - val_loss: 3.7263 - val_sparse_top_k: 0.2114 - lr: 8.3136e-05 - 454ms/epoch - 32ms/step
# Epoch 59/200
# 14/14 - 0s - loss: 3.6211 - sparse_top_k: 0.2568 - val_loss: 3.7265 - val_sparse_top_k: 0.2057 - lr: 8.2581e-05 - 355ms/epoch - 25ms/step
# Epoch 60/200
# 14/14 - 0s - loss: 3.6192 - sparse_top_k: 0.2598 - val_loss: 3.7254 - val_sparse_top_k: 0.2086 - lr: 8.2019e-05 - 364ms/epoch - 26ms/step
# Epoch 61/200
# 14/14 - 0s - loss: 3.6153 - sparse_top_k: 0.2669 - val_loss: 3.7220 - val_sparse_top_k: 0.2086 - lr: 8.1450e-05 - 372ms/epoch - 27ms/step
# Epoch 62/200
# 14/14 - 0s - loss: 3.6072 - sparse_top_k: 0.2528 - val_loss: 3.7200 - val_sparse_top_k: 0.2086 - lr: 8.0875e-05 - 382ms/epoch - 27ms/step
# Epoch 63/200
# 14/14 - 0s - loss: 3.6150 - sparse_top_k: 0.2521 - val_loss: 3.7257 - val_sparse_top_k: 0.1886 - lr: 8.0294e-05 - 381ms/epoch - 27ms/step
# Epoch 64/200
# 14/14 - 0s - loss: 3.6125 - sparse_top_k: 0.2571 - val_loss: 3.7203 - val_sparse_top_k: 0.1971 - lr: 7.9706e-05 - 358ms/epoch - 26ms/step
# Epoch 65/200
# 14/14 - 0s - loss: 3.6059 - sparse_top_k: 0.2676 - val_loss: 3.7216 - val_sparse_top_k: 0.1914 - lr: 7.9112e-05 - 359ms/epoch - 26ms/step
# Epoch 66/200
# 14/14 - 0s - loss: 3.6038 - sparse_top_k: 0.2585 - val_loss: 3.7163 - val_sparse_top_k: 0.1943 - lr: 7.8512e-05 - 383ms/epoch - 27ms/step
# Epoch 67/200
# 14/14 - 0s - loss: 3.5993 - sparse_top_k: 0.2588 - val_loss: 3.7200 - val_sparse_top_k: 0.2057 - lr: 7.7907e-05 - 388ms/epoch - 28ms/step
# Epoch 68/200
# 14/14 - 0s - loss: 3.6074 - sparse_top_k: 0.2558 - val_loss: 3.7200 - val_sparse_top_k: 0.2029 - lr: 7.7296e-05 - 376ms/epoch - 27ms/step
# Epoch 69/200
# 14/14 - 0s - loss: 3.5949 - sparse_top_k: 0.2605 - val_loss: 3.7151 - val_sparse_top_k: 0.1943 - lr: 7.6679e-05 - 356ms/epoch - 25ms/step
# Epoch 70/200
# 14/14 - 0s - loss: 3.5910 - sparse_top_k: 0.2598 - val_loss: 3.7164 - val_sparse_top_k: 0.2086 - lr: 7.6057e-05 - 362ms/epoch - 26ms/step
# Epoch 71/200
# 14/14 - 0s - loss: 3.5939 - sparse_top_k: 0.2642 - val_loss: 3.7144 - val_sparse_top_k: 0.1943 - lr: 7.5430e-05 - 368ms/epoch - 26ms/step
# Epoch 72/200
# 14/14 - 0s - loss: 3.6002 - sparse_top_k: 0.2645 - val_loss: 3.7162 - val_sparse_top_k: 0.1971 - lr: 7.4797e-05 - 375ms/epoch - 27ms/step
# Epoch 73/200
# 14/14 - 0s - loss: 3.5894 - sparse_top_k: 0.2655 - val_loss: 3.7061 - val_sparse_top_k: 0.2057 - lr: 7.4160e-05 - 438ms/epoch - 31ms/step
# Epoch 74/200
# 14/14 - 0s - loss: 3.5834 - sparse_top_k: 0.2676 - val_loss: 3.7167 - val_sparse_top_k: 0.1886 - lr: 7.3518e-05 - 360ms/epoch - 26ms/step
# Epoch 75/200
# 14/14 - 0s - loss: 3.5897 - sparse_top_k: 0.2676 - val_loss: 3.7122 - val_sparse_top_k: 0.2000 - lr: 7.2872e-05 - 367ms/epoch - 26ms/step
# Epoch 76/200
# 14/14 - 0s - loss: 3.5877 - sparse_top_k: 0.2682 - val_loss: 3.7135 - val_sparse_top_k: 0.1943 - lr: 7.2221e-05 - 370ms/epoch - 26ms/step
# Epoch 77/200
# 14/14 - 0s - loss: 3.5751 - sparse_top_k: 0.2686 - val_loss: 3.7150 - val_sparse_top_k: 0.1943 - lr: 7.1566e-05 - 370ms/epoch - 26ms/step
# Epoch 78/200
# 14/14 - 0s - loss: 3.5884 - sparse_top_k: 0.2588 - val_loss: 3.7098 - val_sparse_top_k: 0.1971 - lr: 7.0906e-05 - 383ms/epoch - 27ms/step
# Epoch 79/200
# 14/14 - 0s - loss: 3.5849 - sparse_top_k: 0.2666 - val_loss: 3.7119 - val_sparse_top_k: 0.2029 - lr: 7.0243e-05 - 353ms/epoch - 25ms/step
# Epoch 80/200
# 14/14 - 0s - loss: 3.5783 - sparse_top_k: 0.2736 - val_loss: 3.7118 - val_sparse_top_k: 0.1943 - lr: 6.9576e-05 - 363ms/epoch - 26ms/step
# Epoch 81/200
# 14/14 - 0s - loss: 3.5794 - sparse_top_k: 0.2655 - val_loss: 3.7074 - val_sparse_top_k: 0.1943 - lr: 6.8906e-05 - 367ms/epoch - 26ms/step
# Epoch 82/200
# 14/14 - 0s - loss: 3.5761 - sparse_top_k: 0.2605 - val_loss: 3.7162 - val_sparse_top_k: 0.1943 - lr: 6.8232e-05 - 374ms/epoch - 27ms/step
# Epoch 83/200
# 14/14 - 0s - loss: 3.5747 - sparse_top_k: 0.2743 - val_loss: 3.7108 - val_sparse_top_k: 0.1914 - lr: 6.7555e-05 - 377ms/epoch - 27ms/step
# Epoch 84/200
# 14/14 - 0s - loss: 3.5709 - sparse_top_k: 0.2649 - val_loss: 3.7017 - val_sparse_top_k: 0.2000 - lr: 6.6874e-05 - 375ms/epoch - 27ms/step
# Epoch 85/200
# 14/14 - 0s - loss: 3.5673 - sparse_top_k: 0.2669 - val_loss: 3.7098 - val_sparse_top_k: 0.1943 - lr: 6.6191e-05 - 368ms/epoch - 26ms/step
# Epoch 86/200
# 14/14 - 0s - loss: 3.5685 - sparse_top_k: 0.2703 - val_loss: 3.7087 - val_sparse_top_k: 0.1914 - lr: 6.5505e-05 - 363ms/epoch - 26ms/step
# Epoch 87/200
# 14/14 - 0s - loss: 3.5704 - sparse_top_k: 0.2622 - val_loss: 3.7119 - val_sparse_top_k: 0.1771 - lr: 6.4816e-05 - 371ms/epoch - 27ms/step
# Epoch 88/200
# 14/14 - 0s - loss: 3.5607 - sparse_top_k: 0.2750 - val_loss: 3.7013 - val_sparse_top_k: 0.1914 - lr: 6.4125e-05 - 393ms/epoch - 28ms/step
# Epoch 89/200
# 14/14 - 0s - loss: 3.5650 - sparse_top_k: 0.2666 - val_loss: 3.7128 - val_sparse_top_k: 0.1914 - lr: 6.3432e-05 - 380ms/epoch - 27ms/step
# Epoch 90/200
# 14/14 - 0s - loss: 3.5664 - sparse_top_k: 0.2676 - val_loss: 3.7039 - val_sparse_top_k: 0.2029 - lr: 6.2737e-05 - 355ms/epoch - 25ms/step
# Epoch 91/200
# 14/14 - 0s - loss: 3.5646 - sparse_top_k: 0.2706 - val_loss: 3.7034 - val_sparse_top_k: 0.1971 - lr: 6.2040e-05 - 380ms/epoch - 27ms/step
# Epoch 92/200
# 14/14 - 0s - loss: 3.5592 - sparse_top_k: 0.2773 - val_loss: 3.7088 - val_sparse_top_k: 0.1914 - lr: 6.1341e-05 - 371ms/epoch - 26ms/step
# Epoch 93/200
# 14/14 - 0s - loss: 3.5535 - sparse_top_k: 0.2676 - val_loss: 3.7009 - val_sparse_top_k: 0.1914 - lr: 6.0640e-05 - 408ms/epoch - 29ms/step
# Epoch 94/200
# 14/14 - 0s - loss: 3.5620 - sparse_top_k: 0.2679 - val_loss: 3.7053 - val_sparse_top_k: 0.1886 - lr: 5.9938e-05 - 413ms/epoch - 29ms/step
# Epoch 95/200
# 14/14 - 0s - loss: 3.5507 - sparse_top_k: 0.2706 - val_loss: 3.7032 - val_sparse_top_k: 0.1971 - lr: 5.9235e-05 - 366ms/epoch - 26ms/step
# Epoch 96/200
# 14/14 - 0s - loss: 3.5540 - sparse_top_k: 0.2679 - val_loss: 3.7066 - val_sparse_top_k: 0.1886 - lr: 5.8531e-05 - 407ms/epoch - 29ms/step
# Epoch 97/200
# 14/14 - 0s - loss: 3.5618 - sparse_top_k: 0.2840 - val_loss: 3.7054 - val_sparse_top_k: 0.1829 - lr: 5.7826e-05 - 373ms/epoch - 27ms/step
# Epoch 98/200
# 14/14 - 0s - loss: 3.5510 - sparse_top_k: 0.2659 - val_loss: 3.7014 - val_sparse_top_k: 0.1857 - lr: 5.7120e-05 - 377ms/epoch - 27ms/step
# Epoch 99/200
# 14/14 - 0s - loss: 3.5495 - sparse_top_k: 0.2783 - val_loss: 3.6986 - val_sparse_top_k: 0.1857 - lr: 5.6413e-05 - 375ms/epoch - 27ms/step
# Epoch 100/200
# 14/14 - 0s - loss: 3.5520 - sparse_top_k: 0.2824 - val_loss: 3.7027 - val_sparse_top_k: 0.1743 - lr: 5.5707e-05 - 365ms/epoch - 26ms/step
# Epoch 101/200
# 14/14 - 0s - loss: 3.5461 - sparse_top_k: 0.2797 - val_loss: 3.7010 - val_sparse_top_k: 0.1800 - lr: 5.5000e-05 - 358ms/epoch - 26ms/step
# Epoch 102/200
# 14/14 - 0s - loss: 3.5431 - sparse_top_k: 0.2655 - val_loss: 3.7038 - val_sparse_top_k: 0.1829 - lr: 5.4293e-05 - 385ms/epoch - 27ms/step
# Epoch 103/200
# 14/14 - 0s - loss: 3.5426 - sparse_top_k: 0.2696 - val_loss: 3.7017 - val_sparse_top_k: 0.1829 - lr: 5.3587e-05 - 395ms/epoch - 28ms/step
# Epoch 104/200
# 14/14 - 0s - loss: 3.5450 - sparse_top_k: 0.2699 - val_loss: 3.7038 - val_sparse_top_k: 0.1743 - lr: 5.2880e-05 - 379ms/epoch - 27ms/step
# Epoch 105/200
# 14/14 - 0s - loss: 3.5430 - sparse_top_k: 0.2716 - val_loss: 3.6983 - val_sparse_top_k: 0.1857 - lr: 5.2174e-05 - 372ms/epoch - 27ms/step
# Epoch 106/200
# 14/14 - 0s - loss: 3.5402 - sparse_top_k: 0.2733 - val_loss: 3.7015 - val_sparse_top_k: 0.1857 - lr: 5.1469e-05 - 361ms/epoch - 26ms/step
# Epoch 107/200
# 14/14 - 0s - loss: 3.5432 - sparse_top_k: 0.2736 - val_loss: 3.7002 - val_sparse_top_k: 0.1800 - lr: 5.0765e-05 - 406ms/epoch - 29ms/step
# Epoch 108/200
# 14/14 - 0s - loss: 3.5467 - sparse_top_k: 0.2729 - val_loss: 3.7062 - val_sparse_top_k: 0.1800 - lr: 5.0062e-05 - 389ms/epoch - 28ms/step
# Epoch 109/200
# 14/14 - 0s - loss: 3.5305 - sparse_top_k: 0.2750 - val_loss: 3.6948 - val_sparse_top_k: 0.1800 - lr: 4.9360e-05 - 379ms/epoch - 27ms/step
# Epoch 110/200
# 14/14 - 0s - loss: 3.5328 - sparse_top_k: 0.2813 - val_loss: 3.6983 - val_sparse_top_k: 0.1800 - lr: 4.8659e-05 - 379ms/epoch - 27ms/step
# Epoch 111/200
# 14/14 - 0s - loss: 3.5319 - sparse_top_k: 0.2713 - val_loss: 3.7004 - val_sparse_top_k: 0.1743 - lr: 4.7960e-05 - 371ms/epoch - 26ms/step
# Epoch 112/200
# 14/14 - 0s - loss: 3.5400 - sparse_top_k: 0.2706 - val_loss: 3.7025 - val_sparse_top_k: 0.1714 - lr: 4.7263e-05 - 434ms/epoch - 31ms/step
# Epoch 113/200
# 14/14 - 0s - loss: 3.5373 - sparse_top_k: 0.2743 - val_loss: 3.6956 - val_sparse_top_k: 0.1886 - lr: 4.6568e-05 - 388ms/epoch - 28ms/step
# Epoch 114/200
# 14/14 - 0s - loss: 3.5368 - sparse_top_k: 0.2753 - val_loss: 3.7046 - val_sparse_top_k: 0.1743 - lr: 4.5875e-05 - 392ms/epoch - 28ms/step
# Epoch 115/200
# 14/14 - 0s - loss: 3.5336 - sparse_top_k: 0.2726 - val_loss: 3.7006 - val_sparse_top_k: 0.1800 - lr: 4.5184e-05 - 414ms/epoch - 30ms/step
# Epoch 116/200
# 14/14 - 0s - loss: 3.5289 - sparse_top_k: 0.2760 - val_loss: 3.6991 - val_sparse_top_k: 0.1743 - lr: 4.4495e-05 - 358ms/epoch - 26ms/step
# Epoch 117/200
# 14/14 - 0s - loss: 3.5260 - sparse_top_k: 0.2861 - val_loss: 3.7038 - val_sparse_top_k: 0.1857 - lr: 4.3809e-05 - 358ms/epoch - 26ms/step
# Epoch 118/200
# 14/14 - 0s - loss: 3.5339 - sparse_top_k: 0.2766 - val_loss: 3.6995 - val_sparse_top_k: 0.1771 - lr: 4.3126e-05 - 369ms/epoch - 26ms/step
# Epoch 119/200
# 14/14 - 0s - loss: 3.5242 - sparse_top_k: 0.2837 - val_loss: 3.6989 - val_sparse_top_k: 0.1800 - lr: 4.2445e-05 - 365ms/epoch - 26ms/step
# Epoch 120/200
# 14/14 - 0s - loss: 3.5203 - sparse_top_k: 0.2857 - val_loss: 3.6955 - val_sparse_top_k: 0.1800 - lr: 4.1768e-05 - 397ms/epoch - 28ms/step
# Epoch 121/200
# 14/14 - 0s - loss: 3.5242 - sparse_top_k: 0.2813 - val_loss: 3.6981 - val_sparse_top_k: 0.1857 - lr: 4.1094e-05 - 380ms/epoch - 27ms/step
# Epoch 122/200
# 14/14 - 0s - loss: 3.5286 - sparse_top_k: 0.2790 - val_loss: 3.6983 - val_sparse_top_k: 0.1829 - lr: 4.0424e-05 - 409ms/epoch - 29ms/step
# Epoch 123/200
# 14/14 - 0s - loss: 3.5248 - sparse_top_k: 0.2817 - val_loss: 3.6957 - val_sparse_top_k: 0.1886 - lr: 3.9757e-05 - 359ms/epoch - 26ms/step
# Epoch 124/200
# 14/14 - 0s - loss: 3.5310 - sparse_top_k: 0.2706 - val_loss: 3.7005 - val_sparse_top_k: 0.1800 - lr: 3.9094e-05 - 432ms/epoch - 31ms/step
# Epoch 125/200
# 14/14 - 0s - loss: 3.5240 - sparse_top_k: 0.2753 - val_loss: 3.6970 - val_sparse_top_k: 0.1886 - lr: 3.8434e-05 - 394ms/epoch - 28ms/step
# Epoch 126/200
# 14/14 - 0s - loss: 3.5219 - sparse_top_k: 0.2861 - val_loss: 3.7016 - val_sparse_top_k: 0.1857 - lr: 3.7779e-05 - 368ms/epoch - 26ms/step
# Epoch 127/200
# 14/14 - 0s - loss: 3.5294 - sparse_top_k: 0.2682 - val_loss: 3.6974 - val_sparse_top_k: 0.1886 - lr: 3.7128e-05 - 369ms/epoch - 26ms/step
# Epoch 128/200
# 14/14 - 0s - loss: 3.5246 - sparse_top_k: 0.2723 - val_loss: 3.6980 - val_sparse_top_k: 0.1886 - lr: 3.6482e-05 - 365ms/epoch - 26ms/step
# Epoch 129/200
# 14/14 - 0s - loss: 3.5272 - sparse_top_k: 0.2726 - val_loss: 3.6952 - val_sparse_top_k: 0.1886 - lr: 3.5840e-05 - 398ms/epoch - 28ms/step
# Epoch 130/200
# 14/14 - 0s - loss: 3.5206 - sparse_top_k: 0.2874 - val_loss: 3.6934 - val_sparse_top_k: 0.1800 - lr: 3.5203e-05 - 385ms/epoch - 28ms/step
# Epoch 131/200
# 14/14 - 0s - loss: 3.5220 - sparse_top_k: 0.2813 - val_loss: 3.6948 - val_sparse_top_k: 0.1743 - lr: 3.4570e-05 - 385ms/epoch - 27ms/step
# Epoch 132/200
# 14/14 - 0s - loss: 3.5201 - sparse_top_k: 0.2726 - val_loss: 3.6906 - val_sparse_top_k: 0.1829 - lr: 3.3943e-05 - 363ms/epoch - 26ms/step
# Epoch 133/200
# 14/14 - 0s - loss: 3.5212 - sparse_top_k: 0.2763 - val_loss: 3.6958 - val_sparse_top_k: 0.1800 - lr: 3.3321e-05 - 368ms/epoch - 26ms/step
# Epoch 134/200
# 14/14 - 0s - loss: 3.5172 - sparse_top_k: 0.2776 - val_loss: 3.6962 - val_sparse_top_k: 0.1800 - lr: 3.2704e-05 - 374ms/epoch - 27ms/step
# Epoch 135/200
# 14/14 - 0s - loss: 3.5150 - sparse_top_k: 0.2790 - val_loss: 3.6938 - val_sparse_top_k: 0.1829 - lr: 3.2093e-05 - 369ms/epoch - 26ms/step
# Epoch 136/200
# 14/14 - 0s - loss: 3.5194 - sparse_top_k: 0.2776 - val_loss: 3.6937 - val_sparse_top_k: 0.1829 - lr: 3.1488e-05 - 366ms/epoch - 26ms/step
# Epoch 137/200
# 14/14 - 0s - loss: 3.5134 - sparse_top_k: 0.2827 - val_loss: 3.6973 - val_sparse_top_k: 0.1857 - lr: 3.0888e-05 - 353ms/epoch - 25ms/step
# Epoch 138/200
# 14/14 - 0s - loss: 3.5115 - sparse_top_k: 0.2864 - val_loss: 3.6956 - val_sparse_top_k: 0.1800 - lr: 3.0294e-05 - 371ms/epoch - 26ms/step
# Epoch 139/200
# 14/14 - 0s - loss: 3.5135 - sparse_top_k: 0.2877 - val_loss: 3.6968 - val_sparse_top_k: 0.1771 - lr: 2.9706e-05 - 365ms/epoch - 26ms/step
# Epoch 140/200
# 14/14 - 0s - loss: 3.5183 - sparse_top_k: 0.2800 - val_loss: 3.6967 - val_sparse_top_k: 0.1771 - lr: 2.9125e-05 - 416ms/epoch - 30ms/step
# Epoch 141/200
# 14/14 - 0s - loss: 3.5232 - sparse_top_k: 0.2844 - val_loss: 3.6953 - val_sparse_top_k: 0.1829 - lr: 2.8550e-05 - 378ms/epoch - 27ms/step
# Epoch 142/200
# 14/14 - 0s - loss: 3.5164 - sparse_top_k: 0.2699 - val_loss: 3.6925 - val_sparse_top_k: 0.1800 - lr: 2.7981e-05 - 356ms/epoch - 25ms/step
# Epoch 143/200
# 14/14 - 0s - loss: 3.5152 - sparse_top_k: 0.2783 - val_loss: 3.6950 - val_sparse_top_k: 0.1800 - lr: 2.7419e-05 - 348ms/epoch - 25ms/step
# Epoch 144/200
# 14/14 - 0s - loss: 3.5104 - sparse_top_k: 0.2921 - val_loss: 3.6989 - val_sparse_top_k: 0.1743 - lr: 2.6864e-05 - 346ms/epoch - 25ms/step
# Epoch 145/200
# 14/14 - 0s - loss: 3.5177 - sparse_top_k: 0.2871 - val_loss: 3.6963 - val_sparse_top_k: 0.1743 - lr: 2.6316e-05 - 356ms/epoch - 25ms/step
# Epoch 146/200
# 14/14 - 0s - loss: 3.5111 - sparse_top_k: 0.2887 - val_loss: 3.6911 - val_sparse_top_k: 0.1771 - lr: 2.5775e-05 - 369ms/epoch - 26ms/step
# Epoch 147/200
# 14/14 - 0s - loss: 3.5029 - sparse_top_k: 0.2874 - val_loss: 3.6930 - val_sparse_top_k: 0.1800 - lr: 2.5241e-05 - 372ms/epoch - 27ms/step
# Epoch 148/200
# 14/14 - 0s - loss: 3.5097 - sparse_top_k: 0.2894 - val_loss: 3.6912 - val_sparse_top_k: 0.1800 - lr: 2.4714e-05 - 357ms/epoch - 25ms/step
# Epoch 149/200
# 14/14 - 0s - loss: 3.5081 - sparse_top_k: 0.2824 - val_loss: 3.6916 - val_sparse_top_k: 0.1771 - lr: 2.4195e-05 - 376ms/epoch - 27ms/step
# Epoch 150/200
# 14/14 - 0s - loss: 3.5144 - sparse_top_k: 0.2739 - val_loss: 3.6842 - val_sparse_top_k: 0.1714 - lr: 2.3684e-05 - 422ms/epoch - 30ms/step
# Epoch 151/200
# 14/14 - 0s - loss: 3.5185 - sparse_top_k: 0.2787 - val_loss: 3.6957 - val_sparse_top_k: 0.1800 - lr: 2.3180e-05 - 364ms/epoch - 26ms/step
# Epoch 152/200
# 14/14 - 0s - loss: 3.5061 - sparse_top_k: 0.2790 - val_loss: 3.6928 - val_sparse_top_k: 0.1800 - lr: 2.2684e-05 - 362ms/epoch - 26ms/step
# Epoch 153/200
# 14/14 - 0s - loss: 3.5071 - sparse_top_k: 0.2834 - val_loss: 3.6927 - val_sparse_top_k: 0.1771 - lr: 2.2196e-05 - 346ms/epoch - 25ms/step
# Epoch 154/200
# 14/14 - 0s - loss: 3.5120 - sparse_top_k: 0.2820 - val_loss: 3.6952 - val_sparse_top_k: 0.1743 - lr: 2.1717e-05 - 342ms/epoch - 24ms/step
# Epoch 155/200
# 14/14 - 0s - loss: 3.5138 - sparse_top_k: 0.2847 - val_loss: 3.6920 - val_sparse_top_k: 0.1771 - lr: 2.1245e-05 - 352ms/epoch - 25ms/step
# Epoch 156/200
# 14/14 - 0s - loss: 3.5114 - sparse_top_k: 0.2857 - val_loss: 3.6895 - val_sparse_top_k: 0.1771 - lr: 2.0782e-05 - 365ms/epoch - 26ms/step
# Epoch 157/200
# 14/14 - 0s - loss: 3.5097 - sparse_top_k: 0.2897 - val_loss: 3.6949 - val_sparse_top_k: 0.1743 - lr: 2.0327e-05 - 361ms/epoch - 26ms/step
# Epoch 158/200
# 14/14 - 0s - loss: 3.5133 - sparse_top_k: 0.2793 - val_loss: 3.6956 - val_sparse_top_k: 0.1714 - lr: 1.9881e-05 - 353ms/epoch - 25ms/step
# Epoch 159/200
# 14/14 - 0s - loss: 3.5058 - sparse_top_k: 0.2834 - val_loss: 3.6883 - val_sparse_top_k: 0.1771 - lr: 1.9443e-05 - 345ms/epoch - 25ms/step
# Epoch 160/200
# 14/14 - 0s - loss: 3.5044 - sparse_top_k: 0.2824 - val_loss: 3.6901 - val_sparse_top_k: 0.1771 - lr: 1.9014e-05 - 345ms/epoch - 25ms/step
# Epoch 161/200
# 14/14 - 0s - loss: 3.5061 - sparse_top_k: 0.2780 - val_loss: 3.6941 - val_sparse_top_k: 0.1771 - lr: 1.8594e-05 - 388ms/epoch - 28ms/step
# Epoch 162/200
# 14/14 - 0s - loss: 3.5097 - sparse_top_k: 0.2743 - val_loss: 3.6958 - val_sparse_top_k: 0.1743 - lr: 1.8183e-05 - 368ms/epoch - 26ms/step
# Epoch 163/200
# 14/14 - 0s - loss: 3.5076 - sparse_top_k: 0.2840 - val_loss: 3.6926 - val_sparse_top_k: 0.1800 - lr: 1.7781e-05 - 359ms/epoch - 26ms/step
# Epoch 164/200
# 14/14 - 0s - loss: 3.5011 - sparse_top_k: 0.2874 - val_loss: 3.6917 - val_sparse_top_k: 0.1771 - lr: 1.7389e-05 - 361ms/epoch - 26ms/step
# Epoch 165/200
# 14/14 - 0s - loss: 3.5050 - sparse_top_k: 0.2884 - val_loss: 3.6933 - val_sparse_top_k: 0.1771 - lr: 1.7005e-05 - 438ms/epoch - 31ms/step
# Epoch 166/200
# 14/14 - 1s - loss: 3.5155 - sparse_top_k: 0.2810 - val_loss: 3.6928 - val_sparse_top_k: 0.1800 - lr: 1.6631e-05 - 585ms/epoch - 42ms/step
# Epoch 167/200
# 14/14 - 1s - loss: 3.5002 - sparse_top_k: 0.2807 - val_loss: 3.6942 - val_sparse_top_k: 0.1829 - lr: 1.6267e-05 - 622ms/epoch - 44ms/step
# Epoch 168/200
# 14/14 - 1s - loss: 3.5050 - sparse_top_k: 0.2830 - val_loss: 3.6911 - val_sparse_top_k: 0.1829 - lr: 1.5912e-05 - 582ms/epoch - 42ms/step
# Epoch 169/200
# 14/14 - 0s - loss: 3.5013 - sparse_top_k: 0.2803 - val_loss: 3.6910 - val_sparse_top_k: 0.1829 - lr: 1.5566e-05 - 415ms/epoch - 30ms/step
# Epoch 170/200
# 14/14 - 0s - loss: 3.5103 - sparse_top_k: 0.2807 - val_loss: 3.6960 - val_sparse_top_k: 0.1743 - lr: 1.5231e-05 - 429ms/epoch - 31ms/step
# Epoch 171/200
# 14/14 - 0s - loss: 3.5026 - sparse_top_k: 0.2743 - val_loss: 3.6923 - val_sparse_top_k: 0.1829 - lr: 1.4905e-05 - 440ms/epoch - 31ms/step
# Epoch 172/200
# 14/14 - 0s - loss: 3.5146 - sparse_top_k: 0.2686 - val_loss: 3.6944 - val_sparse_top_k: 0.1800 - lr: 1.4589e-05 - 491ms/epoch - 35ms/step
# Epoch 173/200
# 14/14 - 0s - loss: 3.5021 - sparse_top_k: 0.2807 - val_loss: 3.6924 - val_sparse_top_k: 0.1800 - lr: 1.4283e-05 - 479ms/epoch - 34ms/step
# Epoch 174/200
# 14/14 - 1s - loss: 3.5059 - sparse_top_k: 0.2770 - val_loss: 3.6917 - val_sparse_top_k: 0.1857 - lr: 1.3987e-05 - 535ms/epoch - 38ms/step
# Epoch 175/200
# 14/14 - 0s - loss: 3.5044 - sparse_top_k: 0.2807 - val_loss: 3.6934 - val_sparse_top_k: 0.1829 - lr: 1.3701e-05 - 470ms/epoch - 34ms/step
# Epoch 176/200
# 14/14 - 0s - loss: 3.5022 - sparse_top_k: 0.2803 - val_loss: 3.6906 - val_sparse_top_k: 0.1857 - lr: 1.3425e-05 - 459ms/epoch - 33ms/step
# Epoch 177/200
# 14/14 - 0s - loss: 3.5007 - sparse_top_k: 0.2924 - val_loss: 3.6871 - val_sparse_top_k: 0.1829 - lr: 1.3160e-05 - 424ms/epoch - 30ms/step
# Epoch 178/200
# 14/14 - 0s - loss: 3.4939 - sparse_top_k: 0.2871 - val_loss: 3.6882 - val_sparse_top_k: 0.1829 - lr: 1.2905e-05 - 439ms/epoch - 31ms/step
# Epoch 179/200
# 14/14 - 0s - loss: 3.4971 - sparse_top_k: 0.2813 - val_loss: 3.6895 - val_sparse_top_k: 0.1886 - lr: 1.2660e-05 - 443ms/epoch - 32ms/step
# Epoch 180/200
# 14/14 - 0s - loss: 3.4918 - sparse_top_k: 0.2844 - val_loss: 3.6903 - val_sparse_top_k: 0.1829 - lr: 1.2426e-05 - 446ms/epoch - 32ms/step
# Epoch 181/200
# 14/14 - 0s - loss: 3.5012 - sparse_top_k: 0.2763 - val_loss: 3.6892 - val_sparse_top_k: 0.1886 - lr: 1.2202e-05 - 455ms/epoch - 33ms/step
# Epoch 182/200
# 14/14 - 0s - loss: 3.4971 - sparse_top_k: 0.2850 - val_loss: 3.6913 - val_sparse_top_k: 0.1857 - lr: 1.1989e-05 - 413ms/epoch - 30ms/step
# Epoch 183/200
# 14/14 - 0s - loss: 3.5077 - sparse_top_k: 0.2770 - val_loss: 3.6901 - val_sparse_top_k: 0.1886 - lr: 1.1787e-05 - 460ms/epoch - 33ms/step
# Epoch 184/200
# 14/14 - 0s - loss: 3.4936 - sparse_top_k: 0.3022 - val_loss: 3.6898 - val_sparse_top_k: 0.1857 - lr: 1.1595e-05 - 454ms/epoch - 32ms/step
# Epoch 185/200
# 14/14 - 0s - loss: 3.5008 - sparse_top_k: 0.2850 - val_loss: 3.6910 - val_sparse_top_k: 0.1857 - lr: 1.1414e-05 - 441ms/epoch - 31ms/step
# Epoch 186/200
# 14/14 - 1s - loss: 3.4998 - sparse_top_k: 0.2699 - val_loss: 3.6906 - val_sparse_top_k: 0.1857 - lr: 1.1243e-05 - 579ms/epoch - 41ms/step
# Epoch 187/200
# 14/14 - 1s - loss: 3.4950 - sparse_top_k: 0.2918 - val_loss: 3.6884 - val_sparse_top_k: 0.1857 - lr: 1.1084e-05 - 591ms/epoch - 42ms/step
# Epoch 188/200
# 14/14 - 1s - loss: 3.5033 - sparse_top_k: 0.2750 - val_loss: 3.6910 - val_sparse_top_k: 0.1857 - lr: 1.0935e-05 - 549ms/epoch - 39ms/step
# Epoch 189/200
# 14/14 - 1s - loss: 3.4931 - sparse_top_k: 0.2861 - val_loss: 3.6911 - val_sparse_top_k: 0.1886 - lr: 1.0797e-05 - 525ms/epoch - 38ms/step
# Epoch 190/200
# 14/14 - 0s - loss: 3.4942 - sparse_top_k: 0.2847 - val_loss: 3.6908 - val_sparse_top_k: 0.1886 - lr: 1.0670e-05 - 482ms/epoch - 34ms/step
# Epoch 191/200
# 14/14 - 0s - loss: 3.4960 - sparse_top_k: 0.2911 - val_loss: 3.6906 - val_sparse_top_k: 0.1886 - lr: 1.0554e-05 - 465ms/epoch - 33ms/step
# Epoch 192/200
# 14/14 - 0s - loss: 3.5005 - sparse_top_k: 0.2854 - val_loss: 3.6898 - val_sparse_top_k: 0.1857 - lr: 1.0449e-05 - 448ms/epoch - 32ms/step
# Epoch 193/200
# 14/14 - 0s - loss: 3.5019 - sparse_top_k: 0.2894 - val_loss: 3.6903 - val_sparse_top_k: 0.1886 - lr: 1.0355e-05 - 443ms/epoch - 32ms/step
# Epoch 194/200
# 14/14 - 0s - loss: 3.5038 - sparse_top_k: 0.2864 - val_loss: 3.6922 - val_sparse_top_k: 0.1857 - lr: 1.0272e-05 - 438ms/epoch - 31ms/step
# Epoch 195/200
# 14/14 - 0s - loss: 3.4913 - sparse_top_k: 0.2921 - val_loss: 3.6927 - val_sparse_top_k: 0.1857 - lr: 1.0200e-05 - 457ms/epoch - 33ms/step
# Epoch 196/200
# 14/14 - 0s - loss: 3.5015 - sparse_top_k: 0.2780 - val_loss: 3.6895 - val_sparse_top_k: 0.1857 - lr: 1.0139e-05 - 446ms/epoch - 32ms/step
# Epoch 197/200
# 14/14 - 0s - loss: 3.4962 - sparse_top_k: 0.2797 - val_loss: 3.6897 - val_sparse_top_k: 0.1857 - lr: 1.0089e-05 - 439ms/epoch - 31ms/step
# Epoch 198/200
# 14/14 - 0s - loss: 3.4977 - sparse_top_k: 0.2861 - val_loss: 3.6914 - val_sparse_top_k: 0.1829 - lr: 1.0050e-05 - 396ms/epoch - 28ms/step
# Epoch 199/200
# 14/14 - 0s - loss: 3.4982 - sparse_top_k: 0.2800 - val_loss: 3.6905 - val_sparse_top_k: 0.1829 - lr: 1.0022e-05 - 380ms/epoch - 27ms/step
# Epoch 200/200
# 14/14 - 0s - loss: 3.4929 - sparse_top_k: 0.2817 - val_loss: 3.6919 - val_sparse_top_k: 0.1829 - lr: 1.0006e-05 - 409ms/epoch - 29ms/step

# %%
print(hist['val_sparse_top_k'].max())

plt.figure(figsize = (8, 6))
plt.semilogy(hist['sparse_top_k'], '-r', label = 'Training')
plt.semilogy(hist['val_sparse_top_k'], '-b', label = 'Validation')
plt.ylabel('Sparse Top K Accuracy', fontsize = 14)
plt.xlabel('Epochs', fontsize = 14)
plt.legend(fontsize = 14)
plt.grid()
plt.show()

# %% [markdown]
# # Predict the Test Dataset

# %%
model.load_weights('best_model.hdf5')
pred = model.predict(X_test)
pred = np.argmax(pred, axis = 2)

# %%
for i in range(y_test.shape[0]):
    print('Prediction:\t', pred[i] + 1)
    print('GoundTruth:\t', y_test[i] + 1)
    print('-' * 40)

# %% [markdown]
# # Predict the Future Draw on 2020/Aug/26
# The Beam Search method is use to output 10 possible draws.
# It is worth noting that Replace = False means no duplicate balls.

# %%
X_latest = X_test[-1][1:]
X_latest = np.concatenate([X_latest, y_test[-1].reshape(1, 7)], axis = 0)
X_latest = X_latest.reshape(1, X_latest.shape[0], X_latest.shape[1])
print(X_latest + 1)
# Out:
# [[[ 2  7 11 23 37 45 19]
#   [10 13 14 18 33 34 15]
#   [ 1 24 39 46 49 52 51]
#   [ 4 10 13 24 53 56 22]
#   [ 1 28 42 43 51 58 36]
#   [ 2 40 49 53 56 58 41]
#   [ 6  8 27 31 37 51 20]
#   [10 14 16 22 25 34 21]
#   [21 22 32 36 45 50  5]
#   [19 23 24 28 37 51 12]]]

# %%
# beam search
def beam_search_decoder(data, k, replace = True):
    sequences = [[list(), 0.0]]
    # walk over each step in sequence
    for row in data:
        all_candidates = list()
        # expand each current candidate
        for i in range(len(sequences)):
            seq, score = sequences[i]
            best_k = np.argsort(row)[-k:]
            for j in best_k:
                candidate = [seq + [j], score + math.log(row[j])]
                if replace:
                    all_candidates.append(candidate)
                elif (replace == False) and (len(set(candidate[0])) == len(candidate[0])):
                    all_candidates.append(candidate)
        # order all candidates by score
        ordered = sorted(all_candidates, key = lambda tup:tup[1], reverse = True)
        # select k best
        sequences = ordered[:k]
    return sequences

# %%
pred_latest = model.predict(X_latest)
pred_latest = np.squeeze(pred_latest)
pred_latest_greedy = np.argmax(pred_latest, axis = 1)
print(pred_latest_greedy + 1)
# Out:
# [ 2 16 25 35 47 58 58]

# %%
beam_width = 10
replace = True

result = beam_search_decoder(pred_latest, beam_width, replace)
print('Beam Width:\t', beam_width)
print('Replace:\t', replace)
print('-' * 85)
for seq in result:
    print('Prediction: ', np.array(seq[0]) + 1, '\tLog Likelihood: ', seq[1])
# Out:
# Beam Width:	 10
# Replace:	 True
# -------------------------------------------------------------------------------------
# Prediction:  [ 2 16 25 35 47 58 58] 	Log Likelihood:  -20.062469848796677
# Prediction:  [ 2 16 25 35 45 58 58] 	Log Likelihood:  -20.07747108084795
# Prediction:  [ 2 16 26 35 47 58 58] 	Log Likelihood:  -20.078793081383264
# Prediction:  [ 5 16 25 35 47 58 58] 	Log Likelihood:  -20.087042178875322
# Prediction:  [ 2 16 26 35 45 58 58] 	Log Likelihood:  -20.093794313434536
# Prediction:  [ 5 16 25 35 45 58 58] 	Log Likelihood:  -20.102043410926594
# Prediction:  [ 5 16 26 35 47 58 58] 	Log Likelihood:  -20.103365411461905
# Prediction:  [ 1 16 25 35 47 58 58] 	Log Likelihood:  -20.105053564618615
# Prediction:  [ 2 14 25 35 47 58 58] 	Log Likelihood:  -20.1080181441481
# Prediction:  [ 2 16 29 35 47 58 58] 	Log Likelihood:  -20.116974372260675

# %%
beam_width = 10
replace = False

result = beam_search_decoder(pred_latest, beam_width, replace)
print('Beam Width:\t', beam_width)
print('Replace:\t', replace)
print('-' * 85)
for seq in result:
    print('Prediction: ', np.array(seq[0]) + 1, '\tLog Likelihood: ', seq[1])
# Out:
# Beam Width:	 10
# Replace:	 False
# -------------------------------------------------------------------------------------
# Prediction:  [ 2 16 25 35 47 58 59] 	Log Likelihood:  -20.15269545023026
# Prediction:  [ 2 16 25 35 45 58 59] 	Log Likelihood:  -20.167696682281534
# Prediction:  [ 2 16 26 35 47 58 59] 	Log Likelihood:  -20.169018682816848
# Prediction:  [ 5 16 25 35 47 58 59] 	Log Likelihood:  -20.177267780308906
# Prediction:  [ 2 16 26 35 45 58 59] 	Log Likelihood:  -20.18401991486812
# Prediction:  [ 5 16 25 35 45 58 59] 	Log Likelihood:  -20.19226901236018
# Prediction:  [ 5 16 26 35 47 58 59] 	Log Likelihood:  -20.19359101289549
# Prediction:  [ 1 16 25 35 47 58 59] 	Log Likelihood:  -20.1952791660522
# Prediction:  [ 2 14 25 35 47 58 59] 	Log Likelihood:  -20.198243745581685
# Prediction:  [ 2 16 29 35 47 58 59] 	Log Likelihood:  -20.20719997369426
